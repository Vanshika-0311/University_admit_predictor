# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("Admission_Predict.csv")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.rename(columns={'LOR':'LOR', 'Chance of Admit':'Chance of Admit'} ,inplace=True)

# %%
df.drop('Serial No.', inplace=True, axis=1)

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
df.tail()
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 395              0.82
# 396              0.84
# 397              0.91
# 398              0.67
# 399              0.95

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# ...

# %%
df['CGPA'].value_counts()
# Out:
# 8.00    9
# 8.76    8
# 8.56    7
# 9.11    6
# 8.64    6
#        ..
# 9.32    1
# 9.48    1
# 9.56    1
# 7.28    1
# 7.96    1
# Name: CGPA, Length: 168, dtype: int64

# %%
df['GRE Score'].value_counts()
# Out:
# 324    19
# 312    19
# 316    14
# 322    14
# 314    14
# 325    13
# 321    13
# 311    12
# 317    12
# 327    12
# 320    12
# 326    11
# 313    11
# 308    11
# 323    10
# 315    10
# 300     9
# 329     9
# 319     9
# 318     9
# 340     8
# 310     8
# 301     8
# 299     8
# 304     8
# 331     8
# 307     8
# 305     8
# 298     7
# 334     7
# 332     6
# 328     6
# 306     6
# 309     6
# 330     6
# 336     5
# 296     5
# 303     5
# 302     5
# 335     4
# 295     4
# 338     4
# 297     4
# 333     4
# 339     3
# 294     2
# 290     2
# 337     1
# 293     1
# Name: GRE Score, dtype: int64

# %%
df['LOR '].value_counts()
# Out:
# 3.0    85
# 4.0    77
# 3.5    73
# 4.5    45
# 2.5    39
# 2.0    38
# 5.0    35
# 1.5     7
# 1.0     1
# Name: LOR , dtype: int64

# %%
sns.displot(df['CGPA'])
plt.title('CGPA Distribution')
# Out:
# Text(0.5, 1.0, 'CGPA Distribution')

# %%
sns.displot(df['TOEFL Score'])
plt.title('TOEFL Score')
# Out:
# Text(0.5, 1.0, 'TOEFL Score')

# %%
sns.displot(df['GRE Score'])
plt.title('GRE Score')
# Out:
# Text(0.5, 1.0, 'GRE Score')

# %%
plt.figure(0)
plt.pie(df['SOP'].value_counts(),autopct="%1.2f%%")
plt.title('SOP')
plt.figure(1)
plt.pie(df['LOR '].value_counts(),autopct="%1.1f%%")
plt.title('LOR')
plt.show()

# %%
sns.barplot(df['Chance of Admit '].value_counts().index, df['Chance of Admit '].value_counts())
# Out:
# C:\Users\Public\Pictures\vanshika\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='Chance of Admit '>

# %%
sns.countplot(df['Research'])
plt.title("Research experience")
plt.ylabel('Number of Applicants')
# Out:
# C:\Users\Public\Pictures\vanshika\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Number of Applicants')

# %%
sns.countplot(df['University Rating'])
plt.title("University Rating")
plt.ylabel('Number of Applicants')
# Out:
# C:\Users\Public\Pictures\vanshika\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Number of Applicants')

# %%
df.hist(figsize=(8,8))
# Out:
# array([[<AxesSubplot:title={'center':'GRE Score'}>,
#         <AxesSubplot:title={'center':'TOEFL Score'}>,
#         <AxesSubplot:title={'center':'University Rating'}>],
#        [<AxesSubplot:title={'center':'SOP'}>,
#         <AxesSubplot:title={'center':'LOR '}>,
#         <AxesSubplot:title={'center':'CGPA'}>],
#        [<AxesSubplot:title={'center':'Research'}>,
#         <AxesSubplot:title={'center':'Chance of Admit '}>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.lineplot(data=df,x="GRE Score",y="Chance of Admit ",
            palette="Set1",alpha=0.7)
plt.title("GRE Score vs Chance of Admit")
plt.show()

# %%
sns.relplot(data=df,x="GRE Score",y="Chance of Admit ",hue="Research",
            palette="Set1",alpha=0.7)
plt.title("GRE Score vs Chance of Admit")
plt.show()

# %%
sns.relplot(data=df,x="TOEFL Score",y="Chance of Admit ",hue="Research",
            palette="Set1",alpha=0.7,kind="line",ci=None)
plt.title("TOEFL Score vs Chance of Admit")
plt.show()

# %%
sns.scatterplot(data=df,x="CGPA",y="Chance of Admit ", hue='Research',
            palette="Set1")
plt.title("CGPA vs Chance of Admit")
plt.show()

# %%
sns.barplot(data=df,x="LOR ",y="Chance of Admit ",
            palette="Set3",hue="Research")
plt.title("LOR vs Chance of Admit")
plt.show()

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.835977           0.668976  0.612831
# TOEFL Score         0.835977     1.000000           0.695590  0.657981
# University Rating   0.668976     0.695590           1.000000  0.734523
# SOP                 0.612831     0.657981           0.734523  1.000000
# LOR                 0.557555     0.567721           0.660123  0.729593
# CGPA                0.833060     0.828417           0.746479  0.718144
# Research            0.580391     0.489858           0.447783  0.444029
# Chance of Admit     0.802610     0.791594           0.711250  0.675732
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.557555  0.833060  0.580391          0.802610
# TOEFL Score        0.567721  0.828417  0.489858          0.791594
# University Rating  0.660123  0.746479  0.447783          0.711250
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(4,2, figsize=(10,10))
                     
ax[0,0].boxplot(df['GRE Score'])
ax[0,1].boxplot(df['TOEFL Score'])
ax[1,0].boxplot(df['University Rating'])
ax[1,1].boxplot(df['SOP'])
ax[2,0].boxplot(df['LOR '])
ax[2,1].boxplot(df['Research'])
ax[3,0].boxplot(df['Chance of Admit '])
ax[3,1].boxplot(df['CGPA'])


ax[0,0].set_title("GRE Score")
ax[0,1].set_title("TOEFL Score")
ax[1,0].set_title("University Rating")
ax[1,1].set_title("SOP")
ax[2,0].set_title("LOR")
ax[2,1].set_title("Research")
ax[3,0].set_title('Chance of Admit ')
ax[3,1].set_title('CGPA')


fig.tight_layout()
plt.show()

# %%
df.median()
# Out:
# GRE Score            317.00
# TOEFL Score          107.00
# University Rating      3.00
# SOP                    3.50
# LOR                    3.50
# CGPA                   8.61
# Research               1.00
# Chance of Admit        0.73
# dtype: float64

# %%
df['LOR '] = np.where(df['LOR ']<1.5,3.50,df['LOR '])
df['CGPA'] = np.where(df['CGPA']<7.2,8.61,df['CGPA'])

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].boxplot(df['LOR '])
ax[1].boxplot(df['CGPA'])


ax[0].set_title("LOR")
ax[1].set_title("CGPA")


fig.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (400, 8)

# %%
df.corr()['Chance of Admit '].sort_values(ascending=False)
# Out:
# Chance of Admit      1.000000
# CGPA                 0.863786
# GRE Score            0.802610
# TOEFL Score          0.791594
# University Rating    0.711250
# SOP                  0.675732
# LOR                  0.661223
# Research             0.553202
# Name: Chance of Admit , dtype: float64

# %%
x= df.iloc[:,0:7]
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
y= df.iloc[:,7:]
y.head()
# Out:
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=9)

# %%
# convert the probablity yes or no

# %%
x_train.shape
# Out:
# (320, 7)

# %%
x_test.shape
# Out:
# (80, 7)

# %%
y_train.shape
# Out:
# (320, 1)

# %%
y_test.shape
# Out:
# (80, 1)

# %%
#y1_test= (y_test>0.5)

# %%
#y1_train=(y_train>0.5)

# %%
from sklearn.linear_model import LinearRegression
MLR = LinearRegression()
MLR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=MLR.predict(x_test)
y_pred.reshape(1,-1)
# Out:
# array([[0.49785767, 0.93357337, 0.6631337 , 0.65152582, 0.66425758,
#         0.73223926, 0.67238862, 0.89587241, 0.84394739, 0.47673087,
#         0.58800303, 0.60929217, 0.69572662, 0.67762262, 0.85784502,
#         0.52302731, 0.70552822, 0.70293204, 0.78724717, 0.83559662,
#         0.660149  , 0.88410272, 0.63104646, 0.58424352, 0.74683976,
#         0.61424369, 0.64122653, 0.64834157, 0.56082554, 0.94107421,
#         0.83578237, 0.70993698, 0.5987156 , 0.76227758, 0.5859709 ,
#         0.60874001, 0.80950658, 0.95768974, 0.64935299, 0.69905753,
#         0.90654764, 0.76003596, 0.70145932, 0.6757437 , 0.71993772,
#         0.65184918, 0.58851927, 0.80288402, 0.9362161 , 0.65400336,
#         0.52215359, 0.53125082, 0.85391859, 0.57981877, 0.91884306,
#         0.70472777, 0.74945936, 0.95332097, 0.70910861, 0.85804154,
#         0.80681327, 0.68008089, 0.66103625, 0.6397944 , 0.95323023,
#         0.64556185, 0.70393249, 0.64156924, 0.8579839 , 0.5538892 ,
# ...

# %%
#R2-Score
from sklearn.metrics import accuracy_score,recall_score,roc_auc_score,confusion_matrix, r2_score, classification_report

r2_score_mlr = r2_score(y_test,y_pred)

print("Linear Regression's Score = {:.3f}".format(r2_score_mlr))
# Out:
# Linear Regression's Score = 0.840

# %%
#MSE
from sklearn import metrics
print(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 0.0032616557021427637

# %%
#RMSE
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 0.05711090703309451

# %%
MLR.predict([[337,118,4,4.5,4.5,9.65,1]])
# Out:
# C:\Users\Public\Pictures\vanshika\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[0.94747678]])

# %%
from sklearn.model_selection import GridSearchCV
parameters = { 'kernel':['linear','rbf'],
             'C':[0.1,0.2,0.5,1.0],
             'gamma':['scale','auto']}
clf = GridSearchCV(MLR,param_grid=parameters,verbose = 2)

# %%
import joblib
joblib.dump(MLR , 'MLR.pkl')
# Out:
# ['MLR.pkl']

# %% [markdown]
# # IBM Deployment

# %%
pip install -U ibm-watson-machine-learning
# Out:
# ...
#
# ...
#      ---------------------------------------- 1.8/1.8 MB 6.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 53.3/53.3 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------- 913.9/913.9 kB 29.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 135.6/135.6 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.11.0-py3-none-any.whl size=73641 sha256=df2b6f65a6ac9a195f60c0151fc08f19bae5bdfdb2f33fe431bde7cecd5fdc45
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\d3\a5\34\52d2e378d3d0446989ebcd214af8bad55beecf905258852b9f
# ...

# %%
from ibm_watson_machine_learning import APIClient
import json
